# %%
import pandas as pd
import matplotlib.pyplot as plt
import koreanize_matplotlib
import seaborn as sns
import openpyxl
import pymysql
import pymysql.cursors

# %%
data = './Data/지역별_총사업자수.xlsx'

Business_df = pd.read_excel(data)

# %%
Business_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      19 non-null     object
#  1   2014    19 non-null     object
#  2   2014.1  19 non-null     object
#  3   2014.2  19 non-null     object
#  4   2015    19 non-null     object
#  5   2015.1  19 non-null     object
#  6   2015.2  19 non-null     object
#  7   2016    19 non-null     object
#  8   2016.1  19 non-null     object
#  9   2016.2  19 non-null     object
#  10  2017    19 non-null     object
#  11  2017.1  19 non-null     object
#  12  2017.2  19 non-null     object
#  13  2018    19 non-null     object
#  14  2018.1  19 non-null     object
#  15  2018.2  19 non-null     object
#  16  2019    19 non-null     object
#  17  2019.1  19 non-null     object
#  18  2019.2  19 non-null     object
#  19  2020    19 non-null     object
#  20  2020.1  19 non-null     object
# ...

# %%
Business_df
# Out:
#         년도     2014   2014.1  2014.2     2015   2015.1  2015.2     2016  \
# 0   시도․업태별       총계       신규      폐업       총계       신규      폐업       총계
# 1       소계  6348919  1127246  815624  6702456  1191009  790050  6886938
# 2       서울  1481289   244805  177913  1545885   252462  172078  1557426
# 3       인천   325231    60281   44863   342928    64776   45074   355102
# 4       경기  1516008   279232  202056  1617283   307818  199444  1695675
# 5       강원   191072    30675   22601   200066    32536   21867   205922
# 6       대전   175746    32775   25191   182716    31973   23354   184530
# 7       충북   187079    34071   24538   198101    34786   22454   202612
# 8       충남   245273    43983   30471   260405    47037   29925   268310
# 9       세종    21014     7250    3398    27519     9513    3039    33291
# 10      광주   166286    33156   24680   175168    33400   23029   177475
# 11      전북   212068    38562   26910   222670    38264   26090   226243
# ...

# %%
Business_df = Business_df.T

Business_df
# Out:
#             0        1        2       3        4       5       6       7   \
# 년도      시도․업태별       소계       서울      인천       경기      강원      대전      충북
# 2014        총계  6348919  1481289  325231  1516008  191072  175746  187079
# 2014.1      신규  1127246   244805   60281   279232   30675   32775   34071
# 2014.2      폐업   815624   177913   44863   202056   22601   25191   24538
# 2015        총계  6702456  1545885  342928  1617283  200066  182716  198101
# 2015.1      신규  1191009   252462   64776   307818   32536   31973   34786
# 2015.2      폐업   790050   172078   45074   199444   21867   23354   22454
# 2016        총계  6886938  1557426  355102  1695675  205922  184530  202612
# 2016.1      신규  1226443   249732   70518   330057   35552   32052   35465
# 2016.2      폐업   909202   200304   52110   227624   25626   26063   27161
# 2017        총계  7226329  1601469  379301  1814719  216103  190144  211029
# 2017.1      신규  1284589   256827   77091   352316   36349   32597   35492
# ...

# %%
Business_df
# Out:
# RangeIndex(start=0, stop=19, step=1)
